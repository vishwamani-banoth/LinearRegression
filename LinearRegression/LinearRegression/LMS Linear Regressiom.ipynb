# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Data = pd.read_csv('house.csv')
X = Data['sqft_living']
Y = Data['price']

# %%
A = np.array(list(zip(np.ones(len(X)),X)))
A
# Out:
# array([[1.00e+00, 1.18e+03],
#        [1.00e+00, 2.57e+03],
#        [1.00e+00, 7.70e+02],
#        ...,
#        [1.00e+00, 1.02e+03],
#        [1.00e+00, 1.60e+03],
#        [1.00e+00, 1.02e+03]])

# %% [markdown]
# $w = (A^{T}A)^{-1}A^{T}Y$

# %%
w = np.dot(np.dot(np.linalg.inv(np.dot(A.T,A)),A.T),Y)
w
# Out:
# array([-43867.60153386,    280.80668993])

# %%
plt.scatter(X,Y,color = 'r')

# %%
x = np.linspace(0,14000,100)
y = np.dot(w,np.array([np.ones(len(x)),x]))
plt.plot(x,y,'r')
plt.scatter(X,Y,color='black')
